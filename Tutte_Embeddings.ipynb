# %%
# Imports

# Algorithms:
from koebe.algorithms.incrementalConvexHull import incrConvexHull, orientationPointE3, randomConvexHullE3
from koebe.algorithms.hypPacker import *
from koebe.algorithms.sampling import surfaceSampling, boundarySampling
from koebe.algorithms.poissonDiskSampling import slowAmbientSurfaceSampling, slowAmbientBoundarySampling
from koebe.algorithms.cvt import weightedCVT, worldToImgPixelCoords
from koebe.algorithms.tutteEmbeddings import tutteEmbeddingE2

# Graphics:
from koebe.graphics.spherical2viewer import *
from koebe.graphics.euclidean2viewer import PoincareDiskViewer, makeStyle

# Geometries:
from koebe.geometries.euclidean3 import PointE3, VectorE3, SegmentE3
from koebe.geometries.euclidean2 import SegmentE2, PointE2, VectorE2

# Linear Algebra:
import numpy as np

# Image creation:
from PIL import Image, ImageDraw, ImageFilter

# Other:
import random

# %%
poly = randomConvexHullE3(12)
poly.outerFace = poly.faces[0]

tutteGraph = tutteEmbeddingE2(poly)

# %%
from koebe.graphics.euclidean2viewer import UnitScaleE2Sketch, makeStyle
viewer = UnitScaleE2Sketch()
#viewer.addAll([v.data for v in poly.verts])
segments = [SegmentE2(e.aDart.origin.data, e.aDart.twin.origin.data) for e in tutteGraph.edges]
viewer.addAll(segments)

points = [v.data for v in tutteGraph.verts]
#viewer.addAll(points)

# for point in points:
#     viewer.setStyle(point, makeStyle(fill="#f00"))

for seg in segments:
    viewer.setStyle(seg, makeStyle(stroke="#000", strokeWeight=0.5))
viewer.show()
# Out:
# E2Sketch(height=500, objects='[[{"type": "SegmentE2", "endpoints": [[1.0, 0.0], [-0.4999999999999998, 0.866025…

# %%
dists = [(v.data - PointE3.O).normSq() for v in tutteGraph.verts]
closestToOriginIdx = dists.index(min(dists))
packing, _ = maximalPacking(
    tutteGraph, 
    num_passes=1000, 
    centerDartIdx = tutteGraph.darts.index(tutteGraph.verts[closestToOriginIdx].aDart)
)

# %%
# Run this to view the circle packing
viewer = PoincareDiskViewer(800, 800)
eucCircs = [v.data.toPoincareCircleE2() for v in packing.verts]
viewer.addAll(packing.verts)
edgeSegs = [SegmentE2(PointE2(e.aDart.origin.data.toPoincareCircleE2().center, e.aDart.origin.data.toPoincareCircleE2().center), 
                      PointE2(e.aDart.dest.data.toPoincareCircleE2().center, e.aDart.dest.data.toPoincareCircleE2().center))
           for e in packing.edges]
viewer.addAll(edgeSegs)
viewer.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-42d8cb17900d> in <module>
#       7            for e in packing.edges]
#       8 viewer.addAll(edgeSegs)
# ----> 9 viewer.show()
#
# ~/Documents/Jupyter Notebooks/koebe.py/koebe/graphics/viewer.py in show(self)
#      56
#      57     def show(self):
# ---> 58         self._updateJson()
#      59         display(self._sketch)
#      60
#
# ~/Documents/Jupyter Notebooks/koebe.py/koebe/graphics/viewer.py in _updateJson(self)
#      36
#      37     def _updateJson(self):
# ---> 38         self._sketch.objects = self._toJson()
#      39         self._sketch.objectsDirty = True
#      40
#
# ~/Documents/Jupyter Notebooks/koebe.py/koebe/graphics/viewer.py in _toJson(self)
#      73
#      74     def _toJson(self):
# ---> 75         return json.dumps([d for d in [self.obj_json_convert_func(o, self.getStyle(o)) for o in self._objs] if not d == None])
#
# ~/.pyenv/versions/3.7.3/lib/python3.7/json/__init__.py in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     229         cls is None and indent is None and separators is None and
#     230         default is None and not sort_keys and not kw):
# --> 231         return _default_encoder.encode(obj)
#     232     if cls is None:
#     233         cls = JSONEncoder
#
# ~/.pyenv/versions/3.7.3/lib/python3.7/json/encoder.py in encode(self, o)
#     197         # exceptions aren't as detailed.  The list call should be roughly
#     198         # equivalent to the PySequence_Fast that ''.join() would do.
# --> 199         chunks = self.iterencode(o, _one_shot=True)
#     200         if not isinstance(chunks, (list, tuple)):
#     201             chunks = list(chunks)
#
# ~/.pyenv/versions/3.7.3/lib/python3.7/json/encoder.py in iterencode(self, o, _one_shot)
#     255                 self.key_separator, self.item_separator, self.sort_keys,
#     256                 self.skipkeys, _one_shot)
# --> 257         return _iterencode(o, 0)
#     258
#     259 def _make_iterencode(markers, _default, _encoder, _indent, _floatstr,
#
# ~/.pyenv/versions/3.7.3/lib/python3.7/json/encoder.py in default(self, o)
#     177
#     178         """
# --> 179         raise TypeError(f'Object of type {o.__class__.__name__} '
#     180                         f'is not JSON serializable')
#     181
#
# TypeError: Object of type PointE2 is not JSON serializable
