# %%
# A quick sample construction to showcase how to use koebe.py

from koebe.algorithms.incrementalConvexHull import randomConvexHullE3
from koebe.geometries.spherical2 import DiskS2
from koebe.geometries.euclidean3 import PointE3
from koebe.graphics.spherical2viewer import *

# Generate a random Euclidean3 polyhedron with 10 vertices
polyhedron = randomConvexHullE3(100)

# Grab the point data from the vertices: 
points = [v.data for v in polyhedron.verts]

# Construct the tangent circle for each point as a conical cap
# Each disk will be stored as .data2 on the vertex it is associated with
for v in polyhedron.verts:
    v.data2 = DiskS2(-v.data.x, -v.data.y, -v.data.z, 1)

# Move the vertices of the polyhedron outwards from the sphere a bit so they
# are easier to see: 
fact = 1.5
for i in range(len(points)):
    pt = polyhedron.verts[i].data
    polyhedron.verts[i].data = PointE3(fact * pt.x, fact * pt.y, fact * pt.z)

# %%
# Create an S2 viewer
viewer = S2Viewer(600,600)

# Add all the vertices (this will show the euclidean 3D points associated with each vertex)
viewer.addAll(polyhedron.verts)

# Add the polyhedron's edges to show them as well
viewer.addAll(polyhedron.edges)

# Add all our additionally stored data2 objects, which are disks
viewer.addAll([v.data2 for v in polyhedron.verts])

# Compute the cplanes for each face 
cplanes = [
    CPlaneS2.throughThreeDiskS2(
        f.vertices()[0].data2, 
        f.vertices()[1].data2, 
        f.vertices()[2].data2
    )
    for f in polyhedron.faces
]

# Add all the cplanes to the viewer
viewer.addAll(cplanes)

# Show the viewer
viewer.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-9e1b124d5cd9> in <module>
#      22
#      23 # Add all the cplanes to the viewer
# ---> 24 viewer.addAll(cplanes)
#      25
#      26 # Show the viewer
#
# ~/Documents/Jupyter Notebooks/koebe.py/koebe/graphics/spherical2viewer.py in addAll(self, objs)
#     179     def addAll(self, objs):
#     180         self._objs.extend(objs)
# --> 181         self._updateJson()
#     182
#     183     def _toJson(self):
#
# ~/Documents/Jupyter Notebooks/koebe.py/koebe/graphics/spherical2viewer.py in _updateJson(self)
#     155
#     156     def _updateJson(self):
# --> 157         self._sketch.objects = self._toJson()
#     158         self._sketch.objectsDirty = True
#     159
#
# ~/Documents/Jupyter Notebooks/koebe.py/koebe/graphics/spherical2viewer.py in _toJson(self)
#     182
#     183     def _toJson(self):
# --> 184         return json.dumps([d for d in [_p5_dict(o, self.getStyle(o)) for o in self._objs] if not d == None])
#     185
#     186     def toggleSphere(self):
#
# ~/Documents/Jupyter Notebooks/koebe.py/koebe/graphics/spherical2viewer.py in <listcomp>(.0)
#     182
#     183     def _toJson(self):
# --> 184         return json.dumps([d for d in [_p5_dict(o, self.getStyle(o)) for o in self._objs] if not d == None])
#     185
#     186     def toggleSphere(self):
#
# ~/Documents/Jupyter Notebooks/koebe.py/koebe/graphics/spherical2viewer.py in _p5_dict(obj, style)
#     112         result = _p5_pointE3(obj.toPointE3())
#     113     elif type(obj) is CPlaneS2:
# --> 114         result = _p5_cPlaneS2(obj, style)
#     115     elif type(obj) is DCEL:
#     116         result = _p5_dcel(obj, style)
#
# ~/Documents/Jupyter Notebooks/koebe.py/koebe/graphics/spherical2viewer.py in _p5_cPlaneS2(cplane, style)
#      46
#      47 def _p5_cPlaneS2(cplane, style):
# ---> 48     result = _p5_diskS2(cplane.dualDiskS2)
#      49     if style == None:
#      50         result["style"] = makeStyle(stroke = "#ff0000", strokeWeight = 4)
#
# ~/Documents/Jupyter Notebooks/koebe.py/koebe/graphics/spherical2viewer.py in _p5_diskS2(disk)
#      43             "b3":         tuple(disk.normedBasis3.v),
#      44             "centerDist": disk.centerE3.distTo(PointE3.O),
# ---> 45             "diameter":   disk.radiusE3 * 2.0}
#      46
#      47 def _p5_cPlaneS2(cplane, style):
#
# ~/Documents/Jupyter Notebooks/koebe.py/koebe/geometries/spherical2.py in radiusE3(self)
#     218     @property
#     219     def radiusE3(self):
# --> 220         return math.sqrt(1.0 - (self.centerE3 - PointE3.O).normSq())
#     221
#     222     @property
#
# ValueError: math domain error
